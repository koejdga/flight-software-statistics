# %% [markdown]
# ## First Part: Data Retrieval

# %% [markdown]
# This section proposes a method to retrieve results' amount from Google Scholar. It is done using BeautifulSoup and webscraping. The method is not fully functioning though because quickly responses to requests start to have code 429 (Too Many Requests).

# %% [markdown]
# #### Usage Instuctions
#
# 1. Create file named as the variable *'software_names_filename'* in JSON format. There is default value of the variable which can be changed. Add an array of software names there.
# 2. Similarly, create file named as the variable *'sim_names_filename'* in JSON format. Add an array of simulators' names there.
# 2. Similarly, create file named as the variable *'data_filename'* in JSON format. Add a structure similar to given in "flight_software_sims_data_template.json".
#
# Note: Clear the given in "flight_software_sims_data_template.json" fields.

# %%
# https://scholar.google.com/scholar?q=PX4&hl=en&as_sdt=0%2C5&as_ylo=2020&as_yhi=2021
from bs4 import BeautifulSoup
import requests
import re
import time
import json
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))
from src.utils import valid_years_range, valid_year
from dotenv import load_dotenv
from datetime import datetime
import serpapi
load_dotenv(override=True)
# Out:
# True

# %%
from bs4 import BeautifulSoup
import requests
import re
import time
import json
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))
from src.utils import now_timestamp
from dotenv import load_dotenv
from datetime import datetime

# %%
# Load required variables from .env
load_dotenv(override=True)
software_names_filepath = os.getenv("SOFT_LIST_PATH")
sim_names_filepath = os.getenv("SIM_LIST_PATH")
output_folderpath = os.getenv("OUTPUT_JSON_PATH")
from_semantic_scholar = os.getenv("FROM_SEMANTIC_SCHOLAR") == "true"

# %%
def get_results_amount_from_google_scholar(query: str, year: int = None) -> int:
  if year and not valid_year(year):
        return
  
  url = f"https://serpapi.com/search.json?q={"+".join(query.split(" "))}&engine=google_scholar&as_vis=1&num=1&api_key={os.getenv("SERPAPI_API_KEY")}"
  url = url + f"&as_ylo={year}&as_yhi={year}" if year else url

  response = requests.get(url)
  if response.status_code == 200:
      data = response.json()
      return data["search_information"]["total_results"]
  else: 
      print(f"Could not find url: {url}, response: {response}, {response.text}")
      print(f"Given request: '{query}'")
      return None

# %%
def get_results_amount_from_semantic_scholar(query: str, year: int = None) -> int:
    if year and not valid_year(year):
        return
    
    time.sleep(2)
    url = f"https://api.semanticscholar.org/graph/v1/paper/search?query={"+".join(query.split(" "))}&limit=1"
    url = url + f"&year={year}" if year else url
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        total_results = data.get("total", 0)
        print(f"Total results for '{query} at Semantic Search': {total_results}")
        return total_results
    else:
        print(f"Request to Semantic Scholar with query '{query}' failed with status code {response.status_code}: {response.text}")
        return None

# %%
def get_results_amount(query: str, year: int = None):
    if from_semantic_scholar:
        return get_results_amount_from_semantic_scholar(query, year)
    else:
        return get_results_amount_from_google_scholar(query, (year, year))

# %%
def get_flight_software_names():
    with open(software_names_filepath) as f:
        names = json.load(f)
        print("Loaded flight software names successfully")
        return names
    
def get_simulators_names():
    with open(sim_names_filepath) as f:
        names = json.load(f)
        print("Loaded simulators names successfully")
        return names

# returns filepath of output file
def generate_output_file() -> str:
    filepath = f"{output_folderpath}/flight_soft_sims_data_{now_timestamp()}.json"
    with open(filepath, 'w+') as _: pass
    return filepath

# %%
def add_popularity(name: str, is_software: bool, data: dict, year: int = None):
    entity = "software" if is_software else "sim"

    overall_result = get_results_amount(name, year)
    if overall_result:
        data[f"{entity}_popularities"][name] = overall_result
        print("Added overall popularity of " + name)

    uav_result = get_results_amount(name + " uav", year)
    if uav_result:
        data[f"uav_{entity}_popularities"][name] = uav_result
        print("Added UAV popularity of " + name)
    
    else:
        print("An error occured while adding popularity of " + name)
        if not overall_result:
            print(f"Overall result of {name} not found")
        if not uav_result:
            print(f"UAV result of {name} not found")

# %%
def add_software_and_sim_usage(sim: str, software: str, data: dict):
    res = get_results_amount(f"UAV simulation {software} {sim}")
    if res:
        data["soft_sim_distributions"][software][sim] = res
        print(f"Added distibution of {software} with {sim}")
    else:
        print(f"Could not add distibution of {software} with {sim}")

# %%
def retrieve_data():
    software = get_flight_software_names()
    sims = get_simulators_names()
    output_filepath = generate_output_file()
    data = {
                "software_popularities": {},
                "sim_popularities": {},
                "uav_software_popularities": {},
                "uav_sim_popularities": {},
                "soft_sim_distributions": {}
            }
    
    for soft in software:
        add_popularity(soft, is_software=True, data=data)
        data["soft_sim_distributions"][soft] = {}

        for sim in sims:
            add_popularity(sim, is_software=False, data=data)
            add_software_and_sim_usage(sim, soft, data)

    with open(output_filepath, "w") as f:
        total = {
                "from": "Semantic Scholar" if from_semantic_scholar else "Google Scholar",
                "data": data
                }
        json.dump(total, f, indent=2)

    print(f"Saved received data to '{output_folderpath}'")
    print("End")

# %%
def retrieve_years_data(years_range: tuple[int, int] = None):
    software = get_flight_software_names()
    sims = get_simulators_names()
    output_filepath = generate_output_file()

    if years_range and not valid_years_range(years_range):
        return
    
    result_data = {}
    
    for year in range(years_range[0], years_range[1]):
        data = {
                    "software_popularities": {},
                    "sim_popularities": {},
                    "uav_software_popularities": {},
                    "uav_sim_popularities": {},
                    "soft_sim_distributions": {}
                }
        
        for soft in software:
            add_popularity(soft, is_software=True, data=data, year=year)

        for sim in sims:
            add_popularity(sim, is_software=False, data=data, year=year)

        result_data[f"{year}"] = data

    with open(output_filepath, "w") as f:
        total = {
                "from": "Semantic Scholar" if from_semantic_scholar else "Google Scholar",
                "data": result_data
                }
        json.dump(total, f, indent=2)

    print(f"Saved received data to '{output_folderpath}'")
    print("End")

# %%
retrieve_data()
# Out:
# Loaded flight software names successfully
# Loaded simulators names successfully
# Total results for 'PX4 at Semantic Search': 414
# Added overall popularity of PX4
# Total results for 'PX4 uav at Semantic Search': 115206
# Added UAV popularity of PX4
# Total results for 'Gazebo at Semantic Search': 3423
# Added overall popularity of Gazebo
# Total results for 'Gazebo uav at Semantic Search': 117937
# Added UAV popularity of Gazebo
# Total results for 'UAV simulation PX4 Gazebo at Semantic Search': 413
# Added distibution of PX4 with Gazebo
# Total results for 'Flightmare at Semantic Search': 5
# Added overall popularity of Flightmare
# Total results for 'Flightmare uav at Semantic Search': 114961
# Added UAV popularity of Flightmare
# Total results for 'UAV simulation PX4 Flightmare at Semantic Search': 94
# Added distibution of PX4 with Flightmare
# Total results for 'AirSim at Semantic Search': 387
# Added overall popularity of AirSim
# Total results for 'AirSim uav at Semantic Search': 115207
# Added UAV popularity of AirSim
# Total results for 'UAV simulation PX4 AirSim at Semantic Search': 191
# Added distibution of PX4 with AirSim
# Total results for 'Isaac Sim at Semantic Search': 380385
# Added overall popularity of Isaac Sim
# Total results for 'Isaac Sim uav at Semantic Search': 712
# Added UAV popularity of Isaac Sim
# Total results for 'UAV simulation PX4 Isaac Sim at Semantic Search': 4
# Added distibution of PX4 with Isaac Sim
# Request to Semantic Scholar with query 'Microsoft AirSim' failed with status code 429: {"message": "Too Many Requests. Please wait and try again or apply for a key for higher rate limits. https://www.semanticscholar.org/product/api#api-key-form", "code": "429"}
# Request to Semantic Scholar with query 'Microsoft AirSim uav' failed with status code 429: {"message": "Too Many Requests. Please wait and try again or apply for a key for higher rate limits. https://www.semanticscholar.org/product/api#api-key-form", "code": "429"}
# An error occured while adding popularity of Microsoft AirSim
# Overall result of Microsoft AirSim not found
# UAV result of Microsoft AirSim not found
# Request to Semantic Scholar with query 'UAV simulation PX4 Microsoft AirSim' failed with status code 429: {"message": "Too Many Requests. Please wait and try again or apply for a key for higher rate limits. https://www.semanticscholar.org/product/api#api-key-form", "code": "429"}
# Could not add distibution of PX4 with Microsoft AirSim
# Total results for 'NVIDIA Isaac Sim at Semantic Search': 554
# Added overall popularity of NVIDIA Isaac Sim
# Request to Semantic Scholar with query 'NVIDIA Isaac Sim uav' failed with status code 429: {"message": "Too Many Requests. Please wait and try again or apply for a key for higher rate limits. https://www.semanticscholar.org/product/api#api-key-form", "code": "429"}
# An error occured while adding popularity of NVIDIA Isaac Sim
# UAV result of NVIDIA Isaac Sim not found
# Request to Semantic Scholar with query 'UAV simulation PX4 NVIDIA Isaac Sim' failed with status code 429: {"message": "Too Many Requests. Please wait and try again or apply for a key for higher rate limits. https://www.semanticscholar.org/product/api#api-key-form", "code": "429"}
# Could not add distibution of PX4 with NVIDIA Isaac Sim
# Total results for 'ArduPilot at Semantic Search': 357
# Added overall popularity of ArduPilot
# Total results for 'ArduPilot uav at Semantic Search': 115151
# Added UAV popularity of ArduPilot
# Request to Semantic Scholar with query 'Gazebo' failed with status code 429: {"message": "Too Many Requests. Please wait and try again or apply for a key for higher rate limits. https://www.semanticscholar.org/product/api#api-key-form", "code": "429"}
# Request to Semantic Scholar with query 'Gazebo uav' failed with status code 429: {"message": "Too Many Requests. Please wait and try again or apply for a key for higher rate limits. https://www.semanticscholar.org/product/api#api-key-form", "code": "429"}
# An error occured while adding popularity of Gazebo
# Overall result of Gazebo not found
# UAV result of Gazebo not found
# Total results for 'UAV simulation ArduPilot Gazebo at Semantic Search': 389
# Added distibution of ArduPilot with Gazebo
# Total results for 'Flightmare at Semantic Search': 5
# Added overall popularity of Flightmare
# Total results for 'Flightmare uav at Semantic Search': 114961
# Added UAV popularity of Flightmare
# Total results for 'UAV simulation ArduPilot Flightmare at Semantic Search': 61
# Added distibution of ArduPilot with Flightmare
# Total results for 'AirSim at Semantic Search': 387
# Added overall popularity of AirSim
# Total results for 'AirSim uav at Semantic Search': 115207
# Added UAV popularity of AirSim
# Total results for 'UAV simulation ArduPilot AirSim at Semantic Search': 156
# Added distibution of ArduPilot with AirSim
# Total results for 'Isaac Sim at Semantic Search': 380383
# Added overall popularity of Isaac Sim
# Total results for 'Isaac Sim uav at Semantic Search': 712
# Added UAV popularity of Isaac Sim
# Total results for 'UAV simulation ArduPilot Isaac Sim at Semantic Search': 3
# Added distibution of ArduPilot with Isaac Sim
# Total results for 'Microsoft AirSim at Semantic Search': 149063
# Added overall popularity of Microsoft AirSim
# Total results for 'Microsoft AirSim uav at Semantic Search': 275
# Added UAV popularity of Microsoft AirSim
# Total results for 'UAV simulation ArduPilot Microsoft AirSim at Semantic Search': 21
# Added distibution of ArduPilot with Microsoft AirSim
# Total results for 'NVIDIA Isaac Sim at Semantic Search': 554
# Added overall popularity of NVIDIA Isaac Sim
# Total results for 'NVIDIA Isaac Sim uav at Semantic Search': 47
# Added UAV popularity of NVIDIA Isaac Sim
# Total results for 'UAV simulation ArduPilot NVIDIA Isaac Sim at Semantic Search': 32
# Added distibution of ArduPilot with NVIDIA Isaac Sim
# Total results for 'BetaFlight at Semantic Search': 18
# Added overall popularity of BetaFlight
# Total results for 'BetaFlight uav at Semantic Search': 114970
# Added UAV popularity of BetaFlight
# Total results for 'Gazebo at Semantic Search': 3423
# Added overall popularity of Gazebo
# Total results for 'Gazebo uav at Semantic Search': 117937
# Added UAV popularity of Gazebo
# Total results for 'UAV simulation BetaFlight Gazebo at Semantic Search': 333
# Added distibution of BetaFlight with Gazebo
# Total results for 'Flightmare at Semantic Search': 5
# Added overall popularity of Flightmare
# Total results for 'Flightmare uav at Semantic Search': 114961
# Added UAV popularity of Flightmare
# Total results for 'UAV simulation BetaFlight Flightmare at Semantic Search': 3
# Added distibution of BetaFlight with Flightmare
# Total results for 'AirSim at Semantic Search': 387
# Added overall popularity of AirSim
# Total results for 'AirSim uav at Semantic Search': 115207
# Added UAV popularity of AirSim
# Total results for 'UAV simulation BetaFlight AirSim at Semantic Search': 98
# Added distibution of BetaFlight with AirSim
# Total results for 'Isaac Sim at Semantic Search': 380389
# Added overall popularity of Isaac Sim
# Total results for 'Isaac Sim uav at Semantic Search': 712
# Added UAV popularity of Isaac Sim
# Total results for 'UAV simulation BetaFlight Isaac Sim at Semantic Search': 2
# Added distibution of BetaFlight with Isaac Sim
# Total results for 'Microsoft AirSim at Semantic Search': 149063
# Added overall popularity of Microsoft AirSim
# Total results for 'Microsoft AirSim uav at Semantic Search': 275
# Added UAV popularity of Microsoft AirSim
# Total results for 'UAV simulation BetaFlight Microsoft AirSim at Semantic Search': 19
# Added distibution of BetaFlight with Microsoft AirSim
# Total results for 'NVIDIA Isaac Sim at Semantic Search': 554
# Added overall popularity of NVIDIA Isaac Sim
# Total results for 'NVIDIA Isaac Sim uav at Semantic Search': 47
# Added UAV popularity of NVIDIA Isaac Sim
# Total results for 'UAV simulation BetaFlight NVIDIA Isaac Sim at Semantic Search': 31
# Added distibution of BetaFlight with NVIDIA Isaac Sim
# Total results for 'INAV at Semantic Search': 163
# Added overall popularity of INAV
# Total results for 'INAV uav at Semantic Search': 115112
# Added UAV popularity of INAV
# Total results for 'Gazebo at Semantic Search': 3423
# Added overall popularity of Gazebo
# Total results for 'Gazebo uav at Semantic Search': 117937
# Added UAV popularity of Gazebo
# Total results for 'UAV simulation INAV Gazebo at Semantic Search': 333
# Added distibution of INAV with Gazebo
# Total results for 'Flightmare at Semantic Search': 5
# Added overall popularity of Flightmare
# Total results for 'Flightmare uav at Semantic Search': 114961
# Added UAV popularity of Flightmare
# Total results for 'UAV simulation INAV Flightmare at Semantic Search': 3
# Added distibution of INAV with Flightmare
# Total results for 'AirSim at Semantic Search': 387
# Added overall popularity of AirSim
# Total results for 'AirSim uav at Semantic Search': 115207
# Added UAV popularity of AirSim
# Total results for 'UAV simulation INAV AirSim at Semantic Search': 98
# Added distibution of INAV with AirSim
# Total results for 'Isaac Sim at Semantic Search': 380382
# Added overall popularity of Isaac Sim
# Total results for 'Isaac Sim uav at Semantic Search': 712
# Added UAV popularity of Isaac Sim
# Total results for 'UAV simulation INAV Isaac Sim at Semantic Search': 2
# Added distibution of INAV with Isaac Sim
# Total results for 'Microsoft AirSim at Semantic Search': 149063
# Added overall popularity of Microsoft AirSim
# Total results for 'Microsoft AirSim uav at Semantic Search': 275
# Added UAV popularity of Microsoft AirSim
# Total results for 'UAV simulation INAV Microsoft AirSim at Semantic Search': 19
# Added distibution of INAV with Microsoft AirSim
# Total results for 'NVIDIA Isaac Sim at Semantic Search': 554
# Added overall popularity of NVIDIA Isaac Sim
# Total results for 'NVIDIA Isaac Sim uav at Semantic Search': 47
# Added UAV popularity of NVIDIA Isaac Sim
# Total results for 'UAV simulation INAV NVIDIA Isaac Sim at Semantic Search': 31
# Added distibution of INAV with NVIDIA Isaac Sim
# Saved received data to '/Users/sonyabudilova/Documents/NaUKMA/4_year/диплом/statistics flight software/output/statistics'
# End
